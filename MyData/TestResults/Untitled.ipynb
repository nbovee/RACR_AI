# %%
import pandas
import pathlib

# %%
fp = pathlib.Path.cwd() / "alexnetsplit__2023-10-26T013202.pkl"
fp.exists()
# Out:
# True

# %%
import pickle
with open(fp, "rb") as file:
    df = pickle.load(file)

df.head(50)
# Out:
#                             inference_id  layer_id  split_layer  \
# 0   005c01e2-91b1-4c1b-b618-a7971ea8280a         0          NaN
# 1   005c01e2-91b1-4c1b-b618-a7971ea8280a         1          NaN
# 2   005c01e2-91b1-4c1b-b618-a7971ea8280a         2          NaN
# 3   005c01e2-91b1-4c1b-b618-a7971ea8280a         3          NaN
# 4   0066eafd-10c9-4c50-846d-dffdddc8b6c9         0         10.0
# 5   0066eafd-10c9-4c50-846d-dffdddc8b6c9         1         10.0
# 6   0066eafd-10c9-4c50-846d-dffdddc8b6c9         2         10.0
# 7   0066eafd-10c9-4c50-846d-dffdddc8b6c9         3         10.0
# 8   0066eafd-10c9-4c50-846d-dffdddc8b6c9         4         10.0
# 9   0066eafd-10c9-4c50-846d-dffdddc8b6c9         5         10.0
# 10  0066eafd-10c9-4c50-846d-dffdddc8b6c9         6         10.0
# 11  0066eafd-10c9-4c50-846d-dffdddc8b6c9         7         10.0
# 12  0066eafd-10c9-4c50-846d-dffdddc8b6c9         8         10.0
# 13  0066eafd-10c9-4c50-846d-dffdddc8b6c9         9         10.0
# ...

# %%
len(df)
# Out:
# 5890
